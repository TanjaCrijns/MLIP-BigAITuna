# %%
import cv2
import numpy as np
from scipy.misc import imread, imresize
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (20, 12)

# %%
#CHANGE THIS PATH FOR TESTING
path = r'D:\Users\Tanja\Documents\Master\Machine learning in practice\Project\Data\test_stg1\*'


files = glob.glob(path)
files = np.random.choice(files, 40)
yellow_images = []
color_images = []
for file in files:
    image = imread(file)
    if (np.mean(image[:,:,1])-15) > np.mean(image[:,:,0]) and (np.mean(image[:,:,1])-15) > np.mean(image[:,:,2]) :
        yellow_images.append(image)
    else:
        color_images.append(image)

print "Yellow images:"
for image in yellow_images:
    plt.figure(figsize = (20,2))
    plt.imshow(image)
    plt.show()
    print np.mean(image[:,:,0])
    print np.mean(image[:,:,1])
    print np.mean(image[:,:,2])
    
print "Color images:"
for image in color_images:
    plt.figure(figsize = (20,2))
    plt.imshow(image)
    plt.show()
    print np.mean(image[:,:,0])
    print np.mean(image[:,:,1])
    print np.mean(image[:,:,2])
# Out:
# Yellow images:
# 70.0137760417
# 107.410005425
# 40.6812044271
# 70.561078559
# 107.481228299
# 40.8561642795
# 69.6446983507
# 103.411545139
# 40.4709255642
# 63.4128830295
# 105.161988932
# 60.6435720486
# Color images:
# 119.480846354
# 117.76328125
# 116.918526476
# 68.707521875
# 65.7662697917
# 65.657503125
# 111.943141203
# 108.532239797
# 106.801601001
# 124.889208483
# 123.833786255
# 121.261465285
# 107.647850477
# 109.385198568
# 107.777310113
# 122.452107205
# 117.006988932
# 117.620696615
# 100.977231455
# 100.251934677
# 99.6764469969
# 115.467293837
# 116.018940972
# 123.435653212
# 111.355228125
# 111.998214583
# 109.639633333
# 117.275713071
# 119.208383599
# 111.035531635
# 91.791155599
# 88.3744075521
# 93.1910253906
# 123.596304253
# 114.684327257
# 113.883148872
# 117.275713071
# 119.208383599
# 111.035531635
# 111.108258464
# 106.952411024
# 108.008066406
# 97.0631955295
# 95.5381825087
# 97.5301790365
# 108.8349625
# 111.337735417
# 110.513059375
# ...
